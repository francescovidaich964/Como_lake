# %% [markdown]
# # Como lake: Daily dataset exploration
# The dataset provided by the researchers of PoliMi contains the daily *Levels* (in $cm$), *Inflows* (in $m^3/s$) and *Releases* (in $m^3/s$) of the Como lake from 1946 to 2011. More recent values can be found at this [link](https://adda.laghi.net/homepage.aspx?tab=3&subtab=2&idlago=1). This notebook will be used to explore the dataset and to study the process that produces the inflows values.
#
# Let's start by importing the libraries that will be used and the dataset, we will also add a new column containing the complete datetime of each entry:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import os

from fbprophet import Prophet
import fbprophet.plot as fbp
from statsmodels.graphics import tsaplots
import scipy.stats 

# Import the dataset 
df = pd.read_csv('data/como_data_1946_2011.txt', sep="  ", engine='python')
df['date'] = pd.to_datetime(df[["year", "month", "day"]])
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-80-3d271f65de88> in <module>
#       5 import os
#       6
# ----> 7 from fbprophet import Prophet
#       8 import fbprophet.plot as fbp
#       9 from statsmodels.graphics import tsaplots
#
# ModuleNotFoundError: No module named 'fbprophet'

# %% [markdown]
# # Inflow modelling
# Let's start by plotting a portion of the inflow time series. We will take a look at one of the last available years to check that the data is the same than the one available online [here](https://adda.laghi.net/homepage.aspx?tab=3&subtab=2&idlago=1).

# %%
# Plot sequence of inflows of the last full year
plt.figure(figsize=(14,5))
plt.plot(df.date[df.year==2010], df.inflow[df.year==2010])
plt.xlabel('Datetime')
plt.ylabel('Daily Inflow - '+r'$m^3/s$')
plt.show()

# %% [markdown]
# ## Seasonality
# We already know that there is seasonality, we will repeat the seasonal decomposition of the weekly analysis to obtain the seasonal component using the Prophet libary. Differently from the other analysis, here we also have many more years, thus we will also study the non stationary behavior that the trend will present.
#
# To be more specific, here the library will model the time series by extracting a periodic seasonal component, represented by a Fourier series (by trial and error, the best number of harmonics seems to be `yearly_seasonality = 8`), and using a piecewise linear function (with `n_changepoints` that will be evaluated and accepted with a sensibility that depends on `changepoint_prior_scale`) to model the trend within years.

# %%
# THIS MAY TAKE FEW MINUTES

# format data to be compatible with the library
inflow = df[['date','inflow']]
inflow.columns = ['ds','y']

# Find seasonality (fit it using fourier series of given order)
model = Prophet(yearly_seasonality = 8, 
                weekly_seasonality = False,
                daily_seasonality  = False,
                n_changepoints = 40,
                changepoint_prior_scale=0.5)
model.fit(inflow)

# Build estimated inflows
inflow_estim = model.predict()

# Plot fitted components
model.plot_components(inflow_estim)
plt.show()

# %%
# Plot (few years of) the estimated inflow, starting from point...
start = 2000
model.plot(inflow_estim)
plt.xlabel('Datetime')
plt.ylabel('Daily Inflow - '+r'$m^3/s$')
plt.xlim((start,start+1000))
#plt.ylim(-100,800)
plt.show()

# %% [markdown]
# Another easy way to obtain the trend is to just have one point for each year, averaging all the inflows within it -> Still a piecewise linear function
#
# A more smoother trend could be obtained subtracting the seasonal components and then filtering the inflow values with a moving average (or with another filter that averages out the noise, smoothing the signal). In order to really eliminate the seasonal component, the window lenght should be equal to a multiple of 1 year (365 days). I will choose 2 years in order to reduce the effect of anomalies of any specific year without losing too much information over the trend evolution

# %%
# Smoother trend from MA with a window of 2 years
window_size = 730
inflow_MA = ( df.inflow - inflow_estim.yearly ).rolling(window_size).mean()

# Plot filtered signals
plt.figure(figsize=(14,5))
plt.plot(df.date, inflow_MA)
plt.xlabel('Datetime')
plt.ylabel('Trend of the daily inflow - [$m^3/s$]')
plt.show()

# %% [markdown]
# ## Correlation between subsequent values

# %% [markdown]
# So, let's see if subsequent values are indeed correlated. I would consider them correlated if, after removing the trend and the seasonal component, the inflow value at any point in time is somewhat similar to the preceeding one. It is not sufficient to prove that the original inflow values are correlated because it may be due to the smooth evolution of the trend of the seasonality component, thus giving "just" a time-dependent distribuition of the form $p_t(x)$ (where $x$ is the inflow). If, otherwise, the values are correlated after removing such temporal components, then the inflows could be modelled with a time-dependent distribution that depends also on the previous value, like $p_t(x_t|x_{t-1})$.
#
# I will plot the histogram of the differences between subsequent values of the inflows (after removing trend and seasonal component) and, to be sure that these values are actually correlated, the auto-correlation plot.

# %%
"""
# Plot histogram of differences between subsequent values
plt.hist(inflow.y[1:].values - inflow.y[:-1].values, bins=150)
plt.xlabel('Difference between subsequent inflows - '+r'$m^3/s$')
plt.xlim((-500,500))
plt.show()
"""

# Compute residuals and the diffenence between subsequent values
residuals = inflow.y - inflow_estim.yhat
delta_residuals = residuals[1:].values - residuals[:-1].values

# Plot histogram of differences between subsequent residuals
plt.hist(delta_residuals, bins=150)
plt.xlabel('Difference between subsequent residuals - '+r'$m^3/s$')
plt.xlim((-500,500))
plt.show()

# %%
# Display the autocorrelation plot of the inflow 
# values after removing seasonal component 
fig = tsaplots.plot_acf(residuals, lags=10)
plt.ylabel('Autocorrelation')
plt.xlabel('Lag')
plt.show()

# %% [markdown]
# It is possible to see from this last plot that subsequent values are higly correlated, thus it makes sense having a distribution of the form  $p_t(x_t|x_{t-1})$. Moreover, The differences between consecutive inflows follow a gaussian distribution centered on the previous values (is this reliable?).
#
# How should the distribution $p_t(x_t|x_{t-1})$ be built? Ideas:
#  - For each day in the year, find parameters $\mu_\tau, \sigma_\tau$ (with $\tau\in[1, 365]$) such that the inflow is sampled from the gaussian with $\mu_t = x_{t-1}+\mu_\tau$ and $\sigma_t=\sigma_\tau$. In particular, each distribution is fitted using the residual of that specific day from each year. This approach leads to wrong distribution when $x_{t-1}$ is an "outlier". (*After some thoughts, this is not a good idea*)
#  - Relying more on the seasonality component, for example when considering the lognormal approach used to model the weekly data, we may lose information of a year presenting a different behaviours (i.e. 1976's inflow values were low during all spring and summer and "exploded" during autumn)
#  - Weighted sum between the distribution that depends on time and the distribution that depends on the previous values(?) -> It depends on why we need $p_t(x_t|x_{t-1})$
#      - For the temporal distribution we could use the method based on the lognormal distributions, or we could do something similar to the first idea
#      - For the distribution based on previous values, we could consider the trend of the last $k$ values and

# %% [markdown]
# # Wasserstein distance between consecutive probabilities

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import os
import tqdm
from scipy.stats import wasserstein_distance


# Import the dataset 
df = pd.read_csv('data/como_data_1946_2011.txt', sep="  ", engine='python')
df['date'] = pd.to_datetime(df[["year", "month", "day"]])
df
# Out:
#         day  month    year  level  release  inflow       date
# 0       1.0    1.0  1946.0  1.150   116.00    65.6 1946-01-01
# 1       2.0    1.0  1946.0  1.120    93.00    93.0 1946-01-02
# 2       3.0    1.0  1946.0  1.120    84.00    67.2 1946-01-03
# 3       4.0    1.0  1946.0  1.110    84.00    33.6 1946-01-04
# 4       5.0    1.0  1946.0  1.080    84.00    84.0 1946-01-05
# ...     ...    ...     ...    ...      ...     ...        ...
# 23979  27.0    8.0  2011.0  0.355   196.21   204.6 2011-08-27
# 23980  28.0    8.0  2011.0  0.360   194.42   102.1 2011-08-28
# 23981  29.0    8.0  2011.0  0.305   194.19   160.6 2011-08-29
# 23982  30.0    8.0  2011.0  0.285   189.73    72.3 2011-08-30
# 23983  31.0    8.0  2011.0  0.215   188.29   104.4 2011-08-31
#
# [23984 rows x 7 columns]

# %% [markdown]
# ### One sample estimate

# %%
inflow = df['inflow'].values
W = inflow[:-1] - inflow[1:]
print('Maximum wasserstein distance with one sample: {}'.format(np.max(np.abs(W))))
idx_max = np.argmax(np.abs(W))
df.loc[idx_max:idx_max+1]
# Out:
# Maximum wasserstein distance with one sample: 1098.5
#        day  month    year  level  release  inflow       date
# 17440  1.0   10.0  1993.0  1.355    520.4   528.8 1993-10-01
# 17441  2.0   10.0  1993.0  1.360    610.9  1627.3 1993-10-02

# %%
plt.hist(W)
plt.show()

# %% [markdown]
# ### n samples estimate, overlapping

# %%
def wasserstein_overlapping(inflow, n_samples):
    W_n = np.stack([inflow[i:-n_samples+i+1] for i in range(n_samples-1)]+[inflow[n_samples-1:]]).T
    W_n = [wasserstein_distance(a,b) for a,b in zip(W_n[:-1],W_n[1:])]
    return W_n

# %%
W_over = [np.max(wasserstein_overlapping(inflow, i)) for i in range(1,20)]
plt.plot(W_n)

# %% [markdown]
# ### n samples estimate, non-overlapping

# %%
def wasserstein_non_overlapping(inflow, n_samples):
    W_n = inflow[:len(inflow)//n_samples*n_samples].reshape(-1,n_samples)
    W_n = [wasserstein_distance(a,b) for a,b in zip(W_n[:-1],W_n[1:])]
    return W_n

# %%
W_non_over = [np.max(wasserstein_non_overlapping(inflow, i)) for i in range(1,50)]
plt.plot(W_non_over)

# %% [markdown]
# ### n samples estimate, different years

# %% [markdown]
# We group sample from the same day and month for data over n_years consecutive years

# %%
years = df['year'].unique()
years_list = years[:len(years)//n_years*n_years].reshape(-1,n_years)
unique_month_day = np.unique(df[['month','day']].values,axis=0)
years_list.shape
# Out:
# (22, 3)

# %%
def find_df_by_year(df, year_list):
    return df[[df.iloc[i]['year'] in year_list for i in range(len(df))]]

def inflow_by_year(df, years_list):
    date_inflow = []
    for y in tqdm.tqdm(years_list):
        df_y = find_df_by_year(df, y)
        date_inflow += [df_y[(df_y['month']==date[0]) & (df_y['day']==date[1])]['inflow'].values for date in unique_month_day]
    return date_inflow



def wasserstein_year(df, n_years):
    years = df['year'].unique()
    years_list = years[:len(years)//n_years*n_years].reshape(-1,n_years)
    date_inflow = inflow_by_year(df, years_list)

    W_year = []
    i = 0 
    while i <len(date_inflow)-1:
        if len(date_inflow[i+1])==0:
            i += 2
        elif len(date_inflow[i+1])==0:
            i += 1 
        else:
            W_year.append(wasserstein_distance(date_inflow[i],date_inflow[i+1]))
            i += 1 
    return W_year

# %%
W_year = [np.max(wasserstein_year(df, i)) for i in range(1,10)]
plt.plot(W_year)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 66/66 [07:40<00:00,  6.98s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [02:55<00:00,  5.32s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 22/22 [02:07<00:00,  5.80s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 16/16 [01:35<00:00,  5.95s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [01:12<00:00,  5.60s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [01:04<00:00,  5.83s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:52<00:00,  5.82s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [01:24<00:00, 10.61s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:52<00:00,  7.48s/it]
